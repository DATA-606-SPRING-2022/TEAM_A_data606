# %% [markdown]
# <a href="https://colab.research.google.com/github/chetan7116desai/TEAM_A_data606/blob/main/MainCode/ipynb/Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd "/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS"
# Out:
# [Errno 2] No such file or directory: '/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS'
# /content

# %%
ls "/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS"
# Out:
# 1990VAERSDATA.csv      2001VAERSVAX.csv       2013VAERSSYMPTOMS.csv
# 1990VAERSSYMPTOMS.csv  2002VAERSDATA.csv      2013VAERSVAX.csv
# 1990VAERSVAX.csv       2002VAERSSYMPTOMS.csv  2014VAERSDATA.csv
# 1991VAERSDATA.csv      2002VAERSVAX.csv       2014VAERSSYMPTOMS.csv
# 1991VAERSSYMPTOMS.csv  2003VAERSDATA.csv      2014VAERSVAX.csv
# 1991VAERSVAX.csv       2003VAERSSYMPTOMS.csv  2015VAERSDATA.csv
# 1992VAERSDATA.csv      2003VAERSVAX.csv       2015VAERSSYMPTOMS.csv
# 1992VAERSSYMPTOMS.csv  2004VAERSDATA.csv      2015VAERSVAX.csv
# 1992VAERSVAX.csv       2004VAERSSYMPTOMS.csv  2016VAERSDATA.csv
# 1993VAERSDATA.csv      2004VAERSVAX.csv       2016VAERSSYMPTOMS.csv
# 1993VAERSSYMPTOMS.csv  2005VAERSDATA.csv      2016VAERSVAX.csv
# 1993VAERSVAX.csv       2005VAERSSYMPTOMS.csv  2017VAERSDATA.csv
# 1994VAERSDATA.csv      2005VAERSVAX.csv       2017VAERSSYMPTOMS.csv
# 1994VAERSSYMPTOMS.csv  2006VAERSDATA.csv      2017VAERSVAX.csv
# 1994VAERSVAX.csv       2006VAERSSYMPTOMS.csv  2018VAERSDATA.csv
# 1995VAERSDATA.csv      2006VAERSVAX.csv       2018VAERSSYMPTOMS.csv
# 1995VAERSSYMPTOMS.csv  2007VAERSDATA.csv      2018VAERSVAX.csv
# 1995VAERSVAX.csv       2007VAERSSYMPTOMS.csv  2019VAERSDATA.csv
# 1996VAERSDATA.csv      2007VAERSVAX.csv       2019VAERSSYMPTOMS.csv
# 1996VAERSSYMPTOMS.csv  2008VAERSDATA.csv      2019VAERSVAX.csv
# 1996VAERSVAX.csv       2008VAERSSYMPTOMS.csv  2020VAERSDATA.csv
# 1997VAERSDATA.csv      2008VAERSVAX.csv       2020VAERSSYMPTOMS.csv
# 1997VAERSSYMPTOMS.csv  2009VAERSDATA.csv      2020VAERSVAX.csv
# 1997VAERSVAX.csv       2009VAERSSYMPTOMS.csv  2021VAERSDATA.csv
# 1998VAERSDATA.csv      2009VAERSVAX.csv       2021VAERSSYMPTOMS.csv
# 1998VAERSSYMPTOMS.csv  2010VAERSDATA.csv      2021VAERSVAX.csv
# 1998VAERSVAX.csv       2010VAERSSYMPTOMS.csv  2022VAERSDATA.csv
# 1999VAERSDATA.csv      2010VAERSVAX.csv       2022VAERSSYMPTOMS.csv
# 1999VAERSSYMPTOMS.csv  2011VAERSDATA.csv      2022VAERSVAX.csv
# 1999VAERSVAX.csv       2011VAERSSYMPTOMS.csv  data_vax.csv
# 2000VAERSDATA.csv      2011VAERSVAX.csv       manu_name.csv
# 2000VAERSSYMPTOMS.csv  2012VAERSDATA.csv      NonDomesticVAERSDATA.csv
# 2000VAERSVAX.csv       2012VAERSSYMPTOMS.csv  NonDomesticVAERSSYMPTOMS.csv
# 2001VAERSDATA.csv      2012VAERSVAX.csv       NonDomesticVAERSVAX.csv
# 2001VAERSSYMPTOMS.csv  2013VAERSDATA.csv

# %%
import pandas as pd
import glob

# %% [markdown]
# Code to save all the vaccinations, symtoms, data file and combining them together into 3 different files:
#
# Reference:https://pbpython.com/excel-file-combine.html

# %% [markdown]
# VAERSVAX DATA

# %%
glob.glob("/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/*VAERSVAX.csv")
# Out:
# ['/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/1991VAERSVAX.csv',
#  '/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/1990VAERSVAX.csv',
#  '/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/1994VAERSVAX.csv',
#  '/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/1992VAERSVAX.csv',
#  '/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/1993VAERSVAX.csv',
#  '/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/1996VAERSVAX.csv',
#  '/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/1995VAERSVAX.csv',
#  '/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/1997VAERSVAX.csv',
#  '/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/2000VAERSVAX.csv',
#  '/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/1998VAERSVAX.csv',
#  '/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/1999VAERSVAX.csv',
#  '/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/2001VAERSVAX.csv',
#  '/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/2002VAERSVAX.csv',
#  '/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/2003VAERSVAX.csv',
#  '/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/2005VAERSVAX.csv',
#  '/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/2004VAERSVAX.csv',
#  '/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/2006VAERSVAX.csv',
#  '/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/2007VAERSVAX.csv',
#  '/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/2008VAERSVAX.csv',
#  '/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/2009VAERSVAX.csv',
#  '/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/2010VAERSVAX.csv',
#  '/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/2012VAERSVAX.csv',
#  '/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/2011VAERSVAX.csv',
#  '/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/2014VAERSVAX.csv',
#  '/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/2013VAERSVAX.csv',
#  '/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/2015VAERSVAX.csv',
#  '/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/2016VAERSVAX.csv',
#  '/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/2017VAERSVAX.csv',
#  '/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/2018VAERSVAX.csv',
#  '/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/2019VAERSVAX.csv',
#  '/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/2020VAERSVAX.csv',
#  '/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/2021VAERSVAX.csv',
#  '/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/2022VAERSVAX.csv',
#  '/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/NonDomesticVAERSVAX.csv']

# %%
all_data_vax = pd.DataFrame()
for f in glob.glob("/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/*VAERSVAX.csv"):
    VAX = pd.read_csv(f,encoding='latin1', engine='python')
    df_vax = all_data_vax.append(VAX,ignore_index=True)

# %%
df_vax.head()
# Out:
#    VAERS_ID VAX_TYPE  ... VAX_SITE                            VAX_NAME
# 0     25002      PPV  ...      NaN                  PNEUMO (PNEUMOVAX)
# 1     25010      MMR  ...      NaN  MEASLES + MUMPS + RUBELLA (MMR II)
# 2     25011      HEP  ...      NaN                   HEP B (ENGERIX-B)
# 3     25055      HEP  ...      NaN                   HEP B (ENGERIX-B)
# 4     25056      HEP  ...      NaN                   HEP B (ENGERIX-B)
#
# [5 rows x 8 columns]

# %%
df_vax.to_csv("/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/data_vax.csv")

# %% [markdown]
# VAERSSYMPTOMS

# %%
df_vax.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506017 entries, 0 to 506016
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   VAERS_ID         506017 non-null  int64
#  1   VAX_TYPE         506017 non-null  object
#  2   VAX_MANU         506017 non-null  object
#  3   VAX_LOT          297422 non-null  object
#  4   VAX_DOSE_SERIES  506003 non-null  object
#  5   VAX_ROUTE        298193 non-null  object
#  6   VAX_SITE         152225 non-null  object
#  7   VAX_NAME         506017 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 30.9+ MB

# %%
all_data_symptoms = pd.DataFrame()
for f in glob.glob("/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/*VAERSSYMPTOMS.csv"):
    SYMP = pd.read_csv(f,encoding='latin1', engine='python')
    df_symp = all_data_symptoms.append(SYMP,ignore_index=True)

# %%
df_symp.head()
# Out:
#    VAERS_ID                   SYMPTOM1  ...  SYMPTOM5 SYMPTOMVERSION5
# 0     25002                     Chills  ...       NaN             NaN
# 1     25010                 Bronchitis  ...       NaN             NaN
# 2     25011                 Convulsion  ...       NaN             NaN
# 3     25055  Hepatic function abnormal  ...       NaN             NaN
# 4     25056          Hepatic cirrhosis  ...       NaN             NaN
#
# [5 rows x 11 columns]

# %%
df_symp.to_csv("/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/data_sym.csv")

# %%
df_symp = pd.read_csv("/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/data_sym.csv")

# %%
df_symp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 695132 entries, 0 to 695131
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   VAERS_ID         695132 non-null  int64
#  1   SYMPTOM1         695132 non-null  object
#  2   SYMPTOMVERSION1  695132 non-null  float64
#  3   SYMPTOM2         589241 non-null  object
#  4   SYMPTOMVERSION2  589241 non-null  float64
#  5   SYMPTOM3         486605 non-null  object
#  6   SYMPTOMVERSION3  486605 non-null  float64
#  7   SYMPTOM4         379479 non-null  object
#  8   SYMPTOMVERSION4  379479 non-null  float64
#  9   SYMPTOM5         304272 non-null  object
#  10  SYMPTOMVERSION5  304272 non-null  float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 58.3+ MB

# %% [markdown]
# VAERSDATA

# %%
all_data_DATA = pd.DataFrame()
for f in glob.glob("/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/AllVAERSDataCSVS/*VAERSDATA.csv"):
    DATA = pd.read_csv(f,encoding='latin1', engine='python')
    df_data = all_data_DATA.append(DATA,ignore_index=True)

# %%
df_data.head()
# Out:
#    VAERS_ID    RECVDATE STATE  ...  OFC_VISIT  ER_ED_VISIT  ALLERGIES
# 0     25002  07/02/1990    FR  ...        NaN          NaN        NaN
# 1     25010  07/02/1990    FR  ...        NaN          NaN        NaN
# 2     25011  07/02/1990    FR  ...        NaN          NaN        NaN
# 3     25064  07/02/1990    FR  ...        NaN          NaN        NaN
# 4     25055  07/09/1990    FR  ...        NaN          NaN        NaN
#
# [5 rows x 35 columns]

# %%
df_data.to_csv("/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/data_pat.csv")

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 451105 entries, 0 to 451104
# Data columns (total 35 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   VAERS_ID      451105 non-null  int64
#  1   RECVDATE      451105 non-null  object
#  2   STATE         451105 non-null  object
#  3   AGE_YRS       219234 non-null  float64
#  4   CAGE_YR       31376 non-null   float64
#  5   CAGE_MO       13640 non-null   float64
#  6   SEX           451105 non-null  object
#  7   RPT_DATE      75807 non-null   object
#  8   SYMPTOM_TEXT  451102 non-null  object
#  9   DIED          16686 non-null   object
#  10  DATEDIED      11207 non-null   object
#  11  L_THREAT      18873 non-null   object
#  12  ER_VISIT      7868 non-null    object
#  13  HOSPITAL      116079 non-null  object
#  14  HOSPDAYS      22542 non-null   float64
#  15  X_STAY        2466 non-null    object
#  16  DISABLE       36716 non-null   object
#  17  RECOVD        447313 non-null  object
#  18  VAX_DATE      386537 non-null  object
#  19  ONSET_DATE    387847 non-null  object
#  20  NUMDAYS       348503 non-null  float64
#  21  LAB_DATA      244391 non-null  object
#  22  V_ADMINBY     451105 non-null  object
#  23  V_FUNDBY      76416 non-null   object
#  24  OTHER_MEDS    128969 non-null  object
#  25  CUR_ILL       87371 non-null   object
#  26  HISTORY       196987 non-null  object
#  27  PRIOR_VAX     4199 non-null    object
#  28  SPLTTYPE      448710 non-null  object
#  29  FORM_VERS     451105 non-null  int64
#  30  TODAYS_DATE   374682 non-null  object
#  31  BIRTH_DEFECT  514 non-null     object
#  32  OFC_VISIT     24092 non-null   object
#  33  ER_ED_VISIT   25160 non-null   object
#  34  ALLERGIES     1793 non-null    object
# dtypes: float64(5), int64(2), object(28)
# memory usage: 120.5+ MB

# %% [markdown]
# * df_vax contains all the combined csv files of vaccinations from the year 1990 to 2022
#
# * df_symp contains all the combined csv files of symptoms from the year 1990 to 2022
#
# * df_data contains all the combined csv files of data from the year 1990 to 2022

# %%
print(df_data["VAERS_ID"].nunique())
print(df_symp["VAERS_ID"].nunique())
print(df_vax["VAERS_ID"].nunique())
# Out:
# 451105
# 451105
# 451105

# %%
print(df_data.shape)
print(df_symp.shape)
print(df_vax.shape)
# Out:
# (451105, 35)
# (695132, 11)
# (506017, 8)

# %%
df_covid_data = df_vax[df_vax['VAX_TYPE'] == 'COVID19']
#df_covid_data.drop_duplicates( keep="first", inpla ce=True)
print(df_covid_data["VAERS_ID"].nunique())
# Out:
# 340800

# %%
covis_vaersid = df_covid_data.VAERS_ID.tolist()

# %%
df_covid_data
# Out:
#         VAERS_ID VAX_TYPE  ... VAX_SITE                             VAX_NAME
# 149040    902854  COVID19  ...      NaN  COVID19 (COVID19 (PFIZER-BIONTECH))
# 149041    902855  COVID19  ...      NaN  COVID19 (COVID19 (PFIZER-BIONTECH))
# 149042    902856  COVID19  ...      NaN  COVID19 (COVID19 (PFIZER-BIONTECH))
# 149324    907571  COVID19  ...      NaN  COVID19 (COVID19 (PFIZER-BIONTECH))
# 149326    907573  COVID19  ...      NaN  COVID19 (COVID19 (PFIZER-BIONTECH))
# ...          ...      ...  ...      ...                                  ...
# 506011   2071532  COVID19  ...      NaN          COVID19 (COVID19 (MODERNA))
# 506013   2071536  COVID19  ...      NaN          COVID19 (COVID19 (MODERNA))
# 506014   2071537  COVID19  ...      NaN          COVID19 (COVID19 (MODERNA))
# 506015   2071539  COVID19  ...       LA          COVID19 (COVID19 (MODERNA))
# 506016   2071541  COVID19  ...      NaN          COVID19 (COVID19 (MODERNA))
#
# [342013 rows x 8 columns]

# %%
def sanitycheck(df):
    """
    Generates Unique count, Null Count and Null Percentage for each column in Dataframe
    
    Parameters
    ---------
    Input pandas dataframe
    
    Output: pandas dataframe
    """
    data = []
    for col in df.columns:
        data.append({'Column' : col,'Unique' : len(df[col].unique()),
                'Null Count' : df[col].isnull().sum(),
                'Null Percentage' : round(df[col].isnull().sum()/df.shape[0]*100,2) })
    return pd.DataFrame(data).sort_values(['Null Percentage'],ascending=False)

# %%
sanitycheck(df_covid_data)
# Out:
#      Column  Unique  Null Count  Null Percentage
# 0  VAERS_ID  340800           0              0.0
# 1  VAX_TYPE       1           0              0.0
# 2  VAX_MANU       4           0              0.0
# 3  VAX_NAME       4           0              0.0

# %%
df_covid_data.drop(['VAX_SITE','VAX_ROUTE','VAX_LOT'], axis = 1,inplace = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_covid_data.drop_duplicates( keep="first", inplace=True)
df_covid_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 341917 entries, 149040 to 506016
# Data columns (total 5 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   VAERS_ID         341917 non-null  int64
#  1   VAX_TYPE         341917 non-null  object
#  2   VAX_MANU         341917 non-null  object
#  3   VAX_DOSE_SERIES  341910 non-null  object
#  4   VAX_NAME         341917 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 15.7+ MB
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
df_covid_data.groupby(['VAERS_ID']).size().reset_index().rename(columns={0:'count'}).sort_values("count", ascending=False)
# Out:
#         VAERS_ID  count
# 302888   1996461      4
# 297610   1986831      3
# 338740   2067238      3
# 272558   1934139      3
# 330761   2052167      3
# ...          ...    ...
# 113617   1485849      1
# 113616   1485823      1
# 113615   1485822      1
# 113614   1485821      1
# 340799   2071541      1
#
# [340800 rows x 2 columns]

# %%
df_covid_data[df_covid_data.VAERS_ID == 1996461]
# Out:
#         VAERS_ID VAX_TYPE  ... VAX_DOSE_SERIES                     VAX_NAME
# 466803   1996461  COVID19  ...               3  COVID19 (COVID19 (MODERNA))
# 466804   1996461  COVID19  ...               1  COVID19 (COVID19 (UNKNOWN))
# 466805   1996461  COVID19  ...             UNK  COVID19 (COVID19 (UNKNOWN))
# 466806   1996461  COVID19  ...               2  COVID19 (COVID19 (UNKNOWN))
#
# [4 rows x 5 columns]

# %%
df_covid = df_data.merge(df_covid_data, on="VAERS_ID",how='right')
display(df_covid)
# Out:
#         VAERS_ID  ...                             VAX_NAME
# 0         902854  ...  COVID19 (COVID19 (PFIZER-BIONTECH))
# 1         902855  ...  COVID19 (COVID19 (PFIZER-BIONTECH))
# 2         902856  ...  COVID19 (COVID19 (PFIZER-BIONTECH))
# 3         907571  ...  COVID19 (COVID19 (PFIZER-BIONTECH))
# 4         907573  ...  COVID19 (COVID19 (PFIZER-BIONTECH))
# ...          ...  ...                                  ...
# 341912   2071532  ...          COVID19 (COVID19 (MODERNA))
# 341913   2071536  ...          COVID19 (COVID19 (MODERNA))
# 341914   2071537  ...          COVID19 (COVID19 (MODERNA))
# 341915   2071539  ...          COVID19 (COVID19 (MODERNA))
# 341916   2071541  ...          COVID19 (COVID19 (MODERNA))
#
# [341917 rows x 39 columns]

# %%
print(df_covid["VAERS_ID"].nunique())
# Out:
# 340800

# %%
df_covid[df_covid.duplicated(['VAERS_ID'])]
# Out:
#         VAERS_ID  ...                             VAX_NAME
# 3061      987127  ...          COVID19 (COVID19 (MODERNA))
# 3235      992508  ...  COVID19 (COVID19 (PFIZER-BIONTECH))
# 7436     1016432  ...          COVID19 (COVID19 (UNKNOWN))
# 7884     1021496  ...          COVID19 (COVID19 (MODERNA))
# 13656    1053410  ...          COVID19 (COVID19 (MODERNA))
# ...          ...  ...                                  ...
# 341660   2070567  ...  COVID19 (COVID19 (PFIZER-BIONTECH))
# 341661   2070567  ...          COVID19 (COVID19 (UNKNOWN))
# 341666   2070571  ...          COVID19 (COVID19 (UNKNOWN))
# 341680   2070589  ...          COVID19 (COVID19 (UNKNOWN))
# 341681   2070589  ...          COVID19 (COVID19 (UNKNOWN))
#
# [1117 rows x 39 columns]

# %%
sanitycheck(df_covid)
# Out:
#              Column  Unique  Null Count  Null Percentage
# 23         V_FUNDBY       1      341917           100.00
# 5           CAGE_MO       2      341914           100.00
# 7          RPT_DATE       1      341917           100.00
# 12         ER_VISIT       1      341917           100.00
# 27        PRIOR_VAX     115      341799            99.97
# 31     BIRTH_DEFECT       2      341482            99.87
# 15           X_STAY       2      340887            99.70
# 34        ALLERGIES     643      340361            99.54
# 4           CAGE_YR      92      340212            99.50
# 10         DATEDIED     398      332579            97.27
# 14         HOSPDAYS      91      332098            97.13
# 9              DIED       2      329278            96.30
# 11         L_THREAT       2      327272            95.72
# 32        OFC_VISIT       2      319738            93.51
# 33      ER_ED_VISIT       2      318124            93.04
# 16          DISABLE       2      312893            91.51
# 25          CUR_ILL   21671      303915            88.89
# 13         HOSPITAL       2      269021            78.68
# 24       OTHER_MEDS   46440      262318            76.72
# 3           AGE_YRS     125      197821            57.86
# 26          HISTORY   86354      187524            54.84
# 21         LAB_DATA  129893      155697            45.54
# 20          NUMDAYS     614       63699            18.63
# 18         VAX_DATE     826       38139            11.15
# 19       ONSET_DATE     590       30266             8.85
# 28         SPLTTYPE  288917        1670             0.49
# 17           RECOVD       4          84             0.02
# 35         VAX_TYPE       1           0             0.00
# 36         VAX_MANU       4           0             0.00
# 37  VAX_DOSE_SERIES       8           7             0.00
# 0          VAERS_ID  340800           0             0.00
# 30      TODAYS_DATE     404           6             0.00
# 29        FORM_VERS       1           0             0.00
# 22        V_ADMINBY       8           0             0.00
# 1          RECVDATE     389           0             0.00
# 8      SYMPTOM_TEXT  340605           1             0.00
# 6               SEX       3           0             0.00
# 2             STATE       1           0             0.00
# 38         VAX_NAME       4           0             0.00

# %%
df_covid.drop(['V_FUNDBY','RECVDATE','RPT_DATE','SYMPTOM_TEXT','CAGE_YR','CAGE_MO','V_ADMINBY','FORM_VERS','TODAYS_DATE','SPLTTYPE','VAX_DATE','ONSET_DATE','VAX_NAME','PRIOR_VAX','OFC_VISIT','ER_ED_VISIT'],axis=1,inplace=True)

# %%
df_covid
# Out:
#         VAERS_ID STATE  AGE_YRS  ... VAX_TYPE         VAX_MANU VAX_DOSE_SERIES
# 0         902854    FR     49.0  ...  COVID19  PFIZER\BIONTECH             UNK
# 1         902855    FR      NaN  ...  COVID19  PFIZER\BIONTECH             UNK
# 2         902856    FR      NaN  ...  COVID19  PFIZER\BIONTECH             UNK
# 3         907571    FR      NaN  ...  COVID19  PFIZER\BIONTECH             UNK
# 4         907573    FR      NaN  ...  COVID19  PFIZER\BIONTECH             UNK
# ...          ...   ...      ...  ...      ...              ...             ...
# 341912   2071532    FR     43.0  ...  COVID19          MODERNA               2
# 341913   2071536    FR     44.0  ...  COVID19          MODERNA               3
# 341914   2071537    FR     30.0  ...  COVID19          MODERNA               1
# 341915   2071539    FR     51.0  ...  COVID19          MODERNA               2
# 341916   2071541    FR     68.0  ...  COVID19          MODERNA             UNK
#
# [341917 rows x 23 columns]

# %%
df_covid.to_csv('/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/covid_data.csv')

# %%
df_covid = pd.read_csv('/content/drive/Shareddrives/Team A 606 Capstone Project/Dataset/covid_data.csv')

# %% [markdown]
# #combining all the symptoms into a single column

# %%
df_symp
# Out:
#         Unnamed: 0  VAERS_ID  ...         SYMPTOM5  SYMPTOMVERSION5
# 0                0     25002  ...              NaN              NaN
# 1                1     25010  ...              NaN              NaN
# 2                2     25011  ...              NaN              NaN
# 3                3     25055  ...              NaN              NaN
# 4                4     25056  ...              NaN              NaN
# ...            ...       ...  ...              ...              ...
# 695127      695127   2071536  ...  SARS-CoV-2 test             24.1
# 695128      695128   2071537  ...              NaN              NaN
# 695129      695129   2071539  ...     Paraesthesia             24.1
# 695130      695130   2071539  ...              NaN              NaN
# 695131      695131   2071541  ...              NaN              NaN
#
# [695132 rows x 12 columns]

# %%
df_symp.drop(['SYMPTOMVERSION1','SYMPTOMVERSION2','SYMPTOMVERSION3','SYMPTOMVERSION4','SYMPTOMVERSION5'],axis=1,inplace=True)

# %%
sanitycheck(df_symp)
# Out:
#        Column  Unique  Null Count  Null Percentage
# 6    SYMPTOM5    7258      390860            56.23
# 5    SYMPTOM4    7882      315653            45.41
# 4    SYMPTOM3    8437      208527            30.00
# 3    SYMPTOM2    9068      105891            15.23
# 0  Unnamed: 0  695132           0             0.00
# 1    VAERS_ID  451105           0             0.00
# 2    SYMPTOM1    9416           0             0.00

# %%
df_covid_sym = df_symp[df_symp.VAERS_ID.isin(covis_vaersid)]

# %%
df_covid_sym.VAERS_ID.nunique()
# Out:
# 340800

# %%
df_covid_sym[df_covid_sym.duplicated(['VAERS_ID'])]
# Out:
#         Unnamed: 0  VAERS_ID  ...           SYMPTOM4           SYMPTOM5
# 165204      165204    902854  ...  Throat irritation   Throat tightness
# 165207      165207    902856  ...               Rash  Rash erythematous
# 165208      165208    902856  ...                NaN                NaN
# 165483      165483    907571  ...            Pyrexia          Skin warm
# 165484      165484    907571  ...                NaN                NaN
# ...            ...       ...  ...                ...                ...
# 695093      695093   2071042  ...                NaN                NaN
# 695105      695105   2071477  ...                NaN                NaN
# 695111      695111   2071493  ...                NaN                NaN
# 695118      695118   2071500  ...            Pyrexia                NaN
# 695130      695130   2071539  ...                NaN                NaN
#
# [176819 rows x 7 columns]

# %%
df_symp.duplicated(subset=['VAERS_ID']).sum ()
# Out:
# 244027

# %%
df_symp.loc[df_symp.duplicated(subset=['VAERS_ID']), :]
# Out:
#         Unnamed: 0  ...                              SYMPTOM5
# 11              11  ...                                   NaN
# 17              17  ...                             Urticaria
# 26              26  ...                                   NaN
# 29              29  ...                               Syncope
# 31              31  ...                                   NaN
# ...            ...  ...                                   ...
# 695114      695114  ...                                   NaN
# 695118      695118  ...                                   NaN
# 695125      695125  ...  Vaccination site movement impairment
# 695126      695126  ...                                   NaN
# 695130      695130  ...                                   NaN
#
# [244027 rows x 7 columns]

# %%
cols = ['SYMPTOM1', 'SYMPTOM2', 'SYMPTOM3', 'SYMPTOM4','SYMPTOM5']
df_covid_sym["Symptoms"] = df_covid_sym[cols].apply(lambda x: ','.join(x.dropna()), axis=1)
#df_symp['Symptoms'] = df_symp['SYMPTOM1'] + "," +  df_symp['SYMPTOM2'] + "," +  df_symp['SYMPTOM3'] + "," +  df_symp['SYMPTOM4'] + "," +  df_symp['SYMPTOM5']
#https://stackoverflow.com/questions/45787782/combine-multiple-columns-in-pandas-excluding-nans
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_covid_sym
# Out:
#         Unnamed: 0  ...                                           Symptoms
# 165203      165203  ...  Anaphylactic reaction,Anxiety,Cough,Fatigue,Hy...
# 165204      165204  ...  Limb discomfort,Peripheral circulatory failure...
# 165205      165205  ...  Anaphylactoid reaction,SARS-CoV-2 test negativ...
# 165206      165206  ...  Chest pain,Condition aggravated,Dizziness,Hear...
# 165207      165207  ...  Hypotension,Muscle tightness,Pruritus,Rash,Ras...
# ...            ...  ...                                                ...
# 695127      695127  ...  Fatigue,Herpes zoster,Injection site pain,Pyre...
# 695128      695128  ...                   COVID-19,Fatigue,SARS-CoV-2 test
# 695129      695129  ...  Body temperature,Dysphonia,Feeling cold,Muscle...
# 695130      695130  ...                                    Pyrexia,Seizure
# 695131      695131  ...                     Fatigue,Malaise,Nausea,Syncope
#
# [517619 rows x 8 columns]

# %%
df_covid_sym = df_covid_sym.groupby(['VAERS_ID','Symptoms']).size().reset_index().rename(columns={0:'count'})

# %%
#df_symp.head(30)

df_covid_all_sym = df_covid_sym.groupby('VAERS_ID')['Symptoms'].apply(','.join).reset_index()

# %%
df_covid_all_sym
# Out:
#         VAERS_ID                                           Symptoms
# 0         902854  Anaphylactic reaction,Anxiety,Cough,Fatigue,Hy...
# 1         902855  Anaphylactoid reaction,SARS-CoV-2 test negativ...
# 2         902856  Chest pain,Condition aggravated,Dizziness,Hear...
# 3         907571  Chills,Fatigue,Feeling of body temperature cha...
# 4         907573  Balance disorder,Confusional state,Dizziness,F...
# ...          ...                                                ...
# 340795   2071532  Disturbance in attention,Memory impairment,SAR...
# 340796   2071536  Fatigue,Herpes zoster,Injection site pain,Pyre...
# 340797   2071537                   COVID-19,Fatigue,SARS-CoV-2 test
# 340798   2071539  Body temperature,Dysphonia,Feeling cold,Muscle...
# 340799   2071541                     Fatigue,Malaise,Nausea,Syncope
#
# [340800 rows x 2 columns]

# %%
df_covid_all_sym.VAERS_ID.duplicated().sum()
# Out:
# 0

# %%
df_covid_all_sym.nunique()
# Out:
# VAERS_ID    340800
# Symptoms    227114
# dtype: int64

# %%
df_covid_all_sym[df_covid_all_sym.VAERS_ID ==902854]
# Out:
#    VAERS_ID                                           Symptoms
# 0    902854  Anaphylactic reaction,Anxiety,Cough,Fatigue,Hy...

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
df_covid_all_sym.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 340800 entries, 0 to 340799
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   VAERS_ID  340800 non-null  int64
#  1   Symptoms  340800 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 5.2+ MB

# %%
df_covid_all_sym[df_covid_all_sym.VAERS_ID ==902854].Symptoms
# Out:
# 0    Anaphylactic reaction,Anxiety,Cough,Fatigue,Hy...
# Name: Symptoms, dtype: object

# %%
wordcloud2 = WordCloud(width=1600, height=800, 
            background_color ='white',min_font_size = 10).generate(' '.join(df_covid_all_sym.Symptoms))

# %%
plt.figure(figsize=(15,15))
plt.imshow(wordcloud2)
plt.axis("off")
plt.show()
plt.savefig('/content/drive/Shareddrives/Team A 606 Capstone Project/Plot/sympworlcloud.png')

# %%
unique_ade = [val.strip() for sublist in df_covid_all_sym.Symptoms.dropna().str.split(",").tolist() for val in sublist]

# %%
symptoms_summary = pd.DataFrame(unique_ade,columns=['symptoms']).value_counts(sort=True).reset_index().rename(columns={0:'count'})

# %%
## Drop 15 covid symptoms
symptoms_summary[1:51]
# Out:
#                                             symptoms  count
# 1                                           Headache  56776
# 2                                            Fatigue  47016
# 3                                            Pyrexia  44062
# 4                                           COVID-19  32451
# 5                                             Nausea  31376
# 6                                   Body temperature  27274
# 7                                          Dizziness  27197
# 8                                            Myalgia  26603
# 9                                           Dyspnoea  24127
# 10                                 Pain in extremity  23744
# 11                                            Chills  23675
# 12                                        Arthralgia  23125
# 13                               Vaccination failure  22136
# 14                                           Malaise  21624
# 15                        Blood pressure measurement  20472
# 16                                      Immunisation  19998
# 17                                              Pain  18353
# 18                                        Chest pain  17102
# 19                                     Off label use  16075
# 20                                          Asthenia  15838
# 21                                        Heart rate  14791
# 22                                 Electrocardiogram  14322
# 23                                        Blood test  14295
# 24                                  Drug ineffective  13922
# 25                             Vaccination site pain  13600
# 26                                          Vomiting  13565
# 27                                           Syncope  12765
# 28                                      Paraesthesia  12124
# 29                                      Palpitations  11873
# 30                                   Lymphadenopathy  11724
# 31                   Interchange of vaccine products  11438
# 32                                         Diarrhoea  10881
# 33  Inappropriate schedule of product administration  10454
# 34                                 Oxygen saturation  10408
# 35                                     Hypoaesthesia   9537
# 36                                       Myocarditis   9171
# 37                                     Investigation   9093
# 38                                              Rash   8721
# 39                                       Tachycardia   8485
# 40                                             Cough   8407
# 41                                          Pruritus   8403
# 42                                C-reactive protein   8247
# 43                             Computerised tomogram   7749
# 44                                  Chest discomfort   7306
# 45                          Heavy menstrual bleeding   6830
# 46                            Influenza like illness   6780
# 47                                     Hyperhidrosis   6654
# 48                                    Echocardiogram   6608
# 49                             Loss of consciousness   6558
# 50                                Pulmonary embolism   6452

# %%
plt.figure(figsize=(10,10))
chart = sns.barplot(data=symptoms_summary[1:26], x="symptoms", y="count",palette='Set2')
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
plt.title('To 25 Covid Symptoms')
plt.xlabel('Symptoms')
plt.ylabel('No of cases')
plt.show()
plt.savefig('/content/drive/Shareddrives/Team A 606 Capstone Project/Plot/covidsymptoms.png')
